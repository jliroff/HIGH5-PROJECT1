# %%
import csv
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

file2017 = "resources/Tech_Survey_2017.csv"
file2018 = "resources/Tech_Survey_2018.csv"

DF2018 = pd.read_csv(file2018)
DF2017 = pd.read_csv(file2017)

pd.options.display.max_seq_items = 27000

# %%
DF2017 = DF2017.rename(columns={"How many employees does your company or organization have?": "Number of employees",
                                "Is your employer primarily a tech company/organization?":"Is your employer a tech company?",
                                "Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?": "Does your medical coverage include treatment of mental health?",
                                "Do you currently have a mental health disorder?":"Do you currently have a mental health disorder?",
                                "Have you ever been diagnosed with a mental health disorder?":"Have you ever been diagnosed with a mental health disorder?",
                                "Have you had a mental health disorder in the past?": "Have you had a mental health disorder in the past?",
                                "Do you have a family history of mental illness?":"Do you have a family history of mental illness?",
                                "What is your age?": "What is your age?",
                                "What is your gender?":"What is your gender?",
                                "What country do you <strong>work</strong> in?":"What country do you work in?",
                                "What is your race?": "What is your race?",
                                "Is your primary role within your company related to tech/IT?":"Is your primary role within your company related to tech/IT?",
                                "Do you believe your productivity is ever affected by a mental health issue?":"Do you believe your productivity is ever affected by a mental health issue?",
                                "Overall, how well do you think the tech industry supports employees with mental health issues?":"How well do you think the tech industry supports employees with mental health issues?"                                
                               })

# %%
org_DF2017 = DF2017[[
                    "Number of employees",
                     "Is your employer a tech company?",
                     "Does your medical coverage include treatment of mental health?",
                     "Do you currently have a mental health disorder?",
                     'Do you know the options for mental health care available under your employer-provided health coverage?',
                     "Have you ever been diagnosed with a mental health disorder?",
                     "Have you had a mental health disorder in the past?",
                     "Do you have a family history of mental illness?",
                     "What is your age?",
                     "What is your gender?",
                     "What country do you work in?",
                     "What is your race?",
                     "Is your primary role within your company related to tech/IT?",
                     "Do you believe your productivity is ever affected by a mental health issue?",
                     "How well do you think the tech industry supports employees with mental health issues?",
                     'Anxiety Disorder (Generalized, Social, Phobia, etc).1',
                     'Anxiety Disorder (Generalized, Social, Phobia, etc).2',
                     'Mood Disorder (Depression, Bipolar Disorder, etc).1',
                     'Mood Disorder (Depression, Bipolar Disorder, etc).2',
                     'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1',
                     'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2',
                     'Eating Disorder (Anorexia, Bulimia, etc).1',
                     'Eating Disorder (Anorexia, Bulimia, etc).2',
                     'Attention Deficit Hyperactivity Disorder.1',
                     'Attention Deficit Hyperactivity Disorder.2',
                     'Personality Disorder (Borderline, Antisocial, Paranoid, etc).1',
                     'Personality Disorder (Borderline, Antisocial, Paranoid, etc).2',
                     'Obsessive-Compulsive Disorder.1', 
                     'Obsessive-Compulsive Disorder.2', 
                     'Post-traumatic Stress Disorder',
                     'Post-traumatic Stress Disorder.1',
                     'Stress Response Syndromes.1', 
                     'Stress Response Syndromes.2', 
                     'Dissociative Disorder.1',
                     'Dissociative Disorder.2',
                     'Substance Use Disorder.1',
                     'Substance Use Disorder.2', 
                     'Addictive Disorder.1', 
                     'Addictive Disorder.2',
                     'Other.1',
                     'Other.2',

                    ]]

# %%
DF2018 = DF2018.rename(columns={"How many employees does your company or organization have?": "Number of employees",
                                "Is your employer primarily a tech company/organization?":"Is your employer a tech company?",
                                "Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?": "Does your medical coverage include treatment of mental health?",
                                "Do you currently have a mental health disorder?":"Do you currently have a mental health disorder?",
                                "Have you ever been diagnosed with a mental health disorder?":"Have you ever been diagnosed with a mental health disorder?",
                                "Have you had a mental health disorder in the past?": "Have you had a mental health disorder in the past?",
                                "Do you have a family history of mental illness?":"Do you have a family history of mental illness?",
                                "What is your age?": "What is your age?",
                                "What is your gender?":"What is your gender?",
                                "What country do you <strong>work</strong> in?":"What country do you work in?",
                                "What is your race?": "What is your race?",
                                "Is your primary role within your company related to tech/IT?":"Is your primary role within your company related to tech/IT?",
                                "Do you believe your productivity is ever affected by a mental health issue?":"Do you believe your productivity is ever affected by a mental health issue?",
                                "Overall, how well do you think the tech industry supports employees with mental health issues?":"How well do you think the tech industry supports employees with mental health issues?"                                
                               })

# %%
org_DF2018 = DF2018[[
                    "Number of employees",
                     "Is your employer a tech company?",
                     "Does your medical coverage include treatment of mental health?",
                     "Do you currently have a mental health disorder?",
                     'Do you know the options for mental health care available under your employer-provided health coverage?',
                     "Have you ever been diagnosed with a mental health disorder?",
                     "Have you had a mental health disorder in the past?",
                     "Do you have a family history of mental illness?",
                     "What is your age?",
                     "What is your gender?",
                     "What country do you work in?",
                     "What is your race?",
                     "Is your primary role within your company related to tech/IT?",
                     "Do you believe your productivity is ever affected by a mental health issue?",
                     "How well do you think the tech industry supports employees with mental health issues?",
                     'Anxiety Disorder (Generalized, Social, Phobia, etc).1',
                     'Anxiety Disorder (Generalized, Social, Phobia, etc).2',
                     'Mood Disorder (Depression, Bipolar Disorder, etc).1',
                     'Mood Disorder (Depression, Bipolar Disorder, etc).2',
                     'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1',
                     'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2',
                     'Eating Disorder (Anorexia, Bulimia, etc).1',
                     'Eating Disorder (Anorexia, Bulimia, etc).2',
                     'Attention Deficit Hyperactivity Disorder.1',
                     'Attention Deficit Hyperactivity Disorder.2',
                     'Personality Disorder (Borderline, Antisocial, Paranoid, etc).1',
                     'Personality Disorder (Borderline, Antisocial, Paranoid, etc).2',
                     'Obsessive-Compulsive Disorder.1', 
                     'Obsessive-Compulsive Disorder.2', 
                     'Post-traumatic Stress Disorder',
                     'Post-traumatic Stress Disorder.1',
                     'Stress Response Syndromes.1', 
                     'Stress Response Syndromes.2', 
                     'Dissociative Disorder.1',
                     'Dissociative Disorder.2',
                     'Substance Use Disorder.1',
                     'Substance Use Disorder.2', 
                     'Addictive Disorder.1', 
                     'Addictive Disorder.2',
                     'Other.1',
                     'Other.2',

                    ]]

# %%
frames = [org_DF2018, org_DF2017]
result = pd.concat(frames)

result.fillna("No", inplace=True)

# %%
result["Is your employer a tech company?"] = result["Is your employer a tech company?"].replace({1: "Yes",0:"No"})
result["Does your medical coverage include treatment of mental health?"] = result["Does your medical coverage include treatment of mental health?"].replace({1.0: "yes", 0.0:"No"})
result["Number of employees"] = result["Number of employees"].replace({"No": "No Answer"})
result["What country do you work in?"] = result["What country do you work in?"].replace({"No": "No Answer"})
result["What is your race?"] = result["What is your race?"].replace({"No": "No Answer"})
result["What is your age?"] = result["What is your age?"].replace({"No": "No Answer"})
result["Is your primary role within your company related to tech/IT?"] = result["Is your primary role within your company related to tech/IT?"].replace({1.0: "Yes", 0.0:"No"})
result["How well do you think the tech industry supports employees with mental health issues?"] = result["How well do you think the tech industry supports employees with mental health issues?"].replace({"No": "No Answer"})
result["Anxiety Disorder (Generalized, Social, Phobia, etc).1"] = result["Anxiety Disorder (Generalized, Social, Phobia, etc).1"].replace({"Anxiety Disorder (Generalized, Social, Phobia, etc)": "Yes"})
result["Anxiety Disorder (Generalized, Social, Phobia, etc).2"] = result["Anxiety Disorder (Generalized, Social, Phobia, etc).1"].replace({"Anxiety Disorder (Generalized, Social, Phobia, etc)": "Yes"})
result["Mood Disorder (Depression, Bipolar Disorder, etc).1"] = result["Mood Disorder (Depression, Bipolar Disorder, etc).1"].replace({"Mood Disorder (Depression, Bipolar Disorder, etc)": "Yes"})
result["Mood Disorder (Depression, Bipolar Disorder, etc).2"] = result["Mood Disorder (Depression, Bipolar Disorder, etc).2"].replace({"Mood Disorder (Depression, Bipolar Disorder, etc)": "Yes"})
result["Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2"] = result["Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2"].replace({"Psychotic Disorder (Schizophrenia, Schizoaffective, etc)": "Yes"})
result["Eating Disorder (Anorexia, Bulimia, etc).1"] = result["Eating Disorder (Anorexia, Bulimia, etc).1"].replace({"Eating Disorder (Anorexia, Bulimia, etc)": "Yes"})
result["Eating Disorder (Anorexia, Bulimia, etc).2"] = result["Eating Disorder (Anorexia, Bulimia, etc).2"].replace({"Eating Disorder (Anorexia, Bulimia, etc)": "Yes"})
result["Attention Deficit Hyperactivity Disorder.1"] = result["Attention Deficit Hyperactivity Disorder.1"].replace({"Attention Deficit Hyperactivity Disorder": "Yes"})
result["Attention Deficit Hyperactivity Disorder.2"] = result["Attention Deficit Hyperactivity Disorder.2"].replace({"Attention Deficit Hyperactivity Disorder": "Yes"})
result["Personality Disorder (Borderline, Antisocial, Paranoid, etc).1"] = result["Personality Disorder (Borderline, Antisocial, Paranoid, etc).1"].replace({"Personality Disorder (Borderline, Antisocial, Paranoid, etc)": "Yes"})
result["Personality Disorder (Borderline, Antisocial, Paranoid, etc).2"] = result["Personality Disorder (Borderline, Antisocial, Paranoid, etc).2"].replace({"Personality Disorder (Borderline, Antisocial, Paranoid, etc)": "Yes"})
result["Obsessive-Compulsive Disorder.1"] = result["Obsessive-Compulsive Disorder.1"].replace({"Obsessive-Compulsive Disorder": "Yes"})
result["Obsessive-Compulsive Disorder.2"] = result["Obsessive-Compulsive Disorder.2"].replace({"Obsessive-Compulsive Disorder": "Yes"})
result["Post-traumatic Stress Disorder"] = result["Post-traumatic Stress Disorder"].replace({"Post-traumatic Stress Disorder": "Yes"})
result["Post-traumatic Stress Disorder.1"] = result["Post-traumatic Stress Disorder.1"].replace({"Post-traumatic Stress Disorder": "Yes"})
result["Stress Response Syndromes.1"] = result["Stress Response Syndromes.1"].replace({"Stress Response Syndromes": "Yes"})
result["Stress Response Syndromes.2"] = result["Stress Response Syndromes.2"].replace({"Stress Response Syndromes": "Yes"})
result["Dissociative Disorder.1"] = result["Dissociative Disorder.1"].replace({"Dissociative Disorder": "Yes"})
result["Dissociative Disorder.2"] = result["Dissociative Disorder.2"].replace({"Dissociative Disorder": "Yes"})
result["Substance Use Disorder.1"] = result["Substance Use Disorder.1"].replace({"Substance Use Disorder": "Yes"})
result["Substance Use Disorder.2"] = result["Substance Use Disorder.2"].replace({"Substance Use Disorder": "Yes"})
result["Addictive Disorder.1"] = result["Addictive Disorder.1"].replace({"Addictive Disorder": "Yes"})
result["Addictive Disorder.2"] = result["Addictive Disorder.2"].replace({"Addictive Disorder": "Yes"})
result["Other.1"] = result["Other.1"].replace({"No": "N/A"})
result["Other.2"] = result["Other.2"].replace({"No": "N/A"})

result["Other.1"] = result["Other.1"].replace({"Suicidal": "Other", 
                                               "Asperger's": "Other",
                                               "Autism": "Other",
                                               "Asperger": "Other",
                                               "ADHD": "Other"
                                              })

result["Other.2"] = result["Other.2"].replace({"Gender Dysphoria": "Other", 
                                               "Depression": "Other",
                                               "Autism Spectrum Disorder": "Other",
                                               "Autism": "Other",
                                               "Panic Disorder": "Other",
                                               "Tourette's": "Other",
                                               "Aspergers Syndrome": "Other",
                                               "Codependence": "Other",
                                               "Attention Deficit Disorder (Non-Hyperactive)": "Other",
                                               "Multiple Sclerosis & Mental Health": "Other",
                                               "Depression, Anxiety, Developmental Trauma": "Other",
                                               "Adjustment disorder": "Other",
                                               "Panic disorder": "Other",
                                               "Depression ": "Other",
                                               "ADD": "Other",
                                               "Bipolar": "Other",
                                               "Cyclothymia": "Other"
                                              }) 


result["What is your gender?"] = result["What is your gender?"].replace({"male": "Male", 
                                                                         "M": "Male",
                                                                         "m":"Male",
                                                                         "Male ":"Male",
                                                                         "Man":"Male",
                                                                         "cis male ":"Male",
                                                                         "cis-male":"Male",
                                                                         "male, born with xy chromosoms":"Male",
                                                                         "Male, cis":"Male",
                                                                         "MALE":"Male",
                                                                         "Cis male":"Male",
                                                                         "Cis Male":"Male",
                                                                         "Cis-male":"Male",
                                                                         "Cisgender male":"Male",
                                                                         "cis male":"Male",
                                                                         "cis hetero male":"Male",
                                                                         "male (hey this is the tech industry you're talking about)":"Male",
                                                                         "Mail":"Male",
                                                                         "Malel":"Male",
                                                                         "dude":"Male",
                                                                         "Demiguy":"Male",
                                                                         "Ostensibly Male":"Male",
                                                                         "Male (or female, or both)":"Male",
                                                                         "Male-ish":"Male",
                                                                         "man":"Male",
                                                                         "male/androgynous ":"Male",
                                                                         "Male (cis)":"Male",
                                                                         "Trans man":"Male",
                                                                         "female":"Female",
                                                                         "F":"Female",
                                                                         "f":"Female",
                                                                         "Female ":"Female",
                                                                         "Woman":"Female",
                                                                         "woman":"Female",
                                                                         "Trans female":"Female",
                                                                         "Trans woman":"Female",
                                                                         "Woman-identified":"Female",
                                                                         "uhhhhhhhhh fem genderqueer?":"Female",
                                                                         "Female (cisgender)":"Female",
                                                                         "Female/gender non-binary.":"Female",
                                                                         "Nonbinary/femme":"Female",
                                                                         "Cis female ":"Female",
                                                                         "cis female":"Female",
                                                                         "*shrug emoji* (F)":"Female",
                                                                         "Cis-Female":"Female",
                                                                         "trans woman":"Female",
                                                                         "My sex is female.":"Female",
                                                                         "gender non-conforming woman":"Female",
                                                                         "Female (cis) ":"Female",
                                                                         "cisgender female":"Female",
                                                                         "Transfeminine":"Female",
                                                                         "female (cis)":"Female",
                                                                         "femail":"Female",
                                                                         "femalw":"Female",
                                                                         "Female-ish":"Female",
                                                                         "cis-Female":"Female",
                                                                         "female (cisgender)":"Female",
                                                                         "Cisgendered woman":"Female",
                                                                         "F, cisgender":"Female",
                                                                         "Genderqueer demigirl":"Female",
                                                                         "I identify as female" :"Female",
                                                                         "Cis woman":"Female",
                                                                         "She/her/they/them":"Female",
                                                                         "No":"Other",
                                                                         "Nonbinary":"Other",
                                                                         "Genderfluid":"Other",
                                                                         "Genderqueer":"Other",
                                                                         "non-binary":"Other",
                                                                         "sometimes":"Other",
                                                                         "non binary":"Other",
                                                                         "transgender":"Other",
                                                                         "NB":"Other",
                                                                         "Genderqueer/non-binary":"Other",
                                                                         "Agender":"Other",
                                                                         "\-":"Other",
                                                                         "God King of the Valajar":"Other",
                                                                         "nonbinary":"Other",
                                                                         "SWM":"Other",
                                                                         "Non binary":"Other",
                                                                         "None":"Other",
                                                                         "Contextual":"Other",
                                                                         "genderfluid":"Other",
                                                                         "Non-binary":"Other",
                                                                         "none":"Other",
                                                                         "Agender/genderfluid":"Other"
                                                                        })

# %%
anxiety = result[["Anxiety Disorder (Generalized, Social, Phobia, etc).1", "Anxiety Disorder (Generalized, Social, Phobia, etc).2"]]
anxiety["Anxiety Disorder (Generalized, Social, Phobia, etc).1"] = anxiety["Anxiety Disorder (Generalized, Social, Phobia, etc).1"].replace({"No": 0,"Yes": 1})
anxiety["Anxiety Disorder (Generalized, Social, Phobia, etc).2"] = anxiety["Anxiety Disorder (Generalized, Social, Phobia, etc).2"].replace({"No": 0,"Yes": 1})
anxiety["Anxiety Disorder (Generalized, Social, Phobia, etc)"] = anxiety["Anxiety Disorder (Generalized, Social, Phobia, etc).1"] + anxiety["Anxiety Disorder (Generalized, Social, Phobia, etc).2"]

# same add one of the old columns 

mood = result[["Mood Disorder (Depression, Bipolar Disorder, etc).1","Mood Disorder (Depression, Bipolar Disorder, etc).2"]]
mood["Mood Disorder (Depression, Bipolar Disorder, etc).1"] = mood["Mood Disorder (Depression, Bipolar Disorder, etc).1"].replace({"No": 0,"Yes": 1})
mood["Mood Disorder (Depression, Bipolar Disorder, etc).2"] = mood["Mood Disorder (Depression, Bipolar Disorder, etc).2"].replace({"No": 0,"Yes": 1})
mood["Mood Disorder (Depression, Bipolar Disorder, etc)"] = mood["Mood Disorder (Depression, Bipolar Disorder, etc).1"] + mood["Mood Disorder (Depression, Bipolar Disorder, etc).2"]

# differences add new column - mood

Psychotic = result[["Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1", "Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2"]]
Psychotic["Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1"] = Psychotic["Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1"].replace({"No": 0,"Yes": 1})
Psychotic["Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2"] = Psychotic["Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2"].replace({"No": 0,"Yes": 1})
Psychotic["Psychotic Disorder (Schizophrenia, Schizoaffective, etc)"] = Psychotic["Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1"] + Psychotic["Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2"]

# differences add new column - Psychotic

Eating = result[["Eating Disorder (Anorexia, Bulimia, etc).1", "Eating Disorder (Anorexia, Bulimia, etc).2"]]
Eating["Eating Disorder (Anorexia, Bulimia, etc).1"] = Eating["Eating Disorder (Anorexia, Bulimia, etc).1"].replace({"No": 0,"Yes": 1})
Eating["Eating Disorder (Anorexia, Bulimia, etc).2"] = Eating["Eating Disorder (Anorexia, Bulimia, etc).2"].replace({"No": 0,"Yes": 1})
Eating["Eating Disorder (Anorexia, Bulimia, etc)"] = Eating["Eating Disorder (Anorexia, Bulimia, etc).1"] + Eating["Eating Disorder (Anorexia, Bulimia, etc).2"]

# differences add new column - Eating


ADHD = result[["Attention Deficit Hyperactivity Disorder.1", "Attention Deficit Hyperactivity Disorder.2"]]
ADHD["Attention Deficit Hyperactivity Disorder.1"] = ADHD["Attention Deficit Hyperactivity Disorder.1"].replace({"No": 0,"Yes": 1})
ADHD["Attention Deficit Hyperactivity Disorder.2"] = ADHD["Attention Deficit Hyperactivity Disorder.2"].replace({"No": 0,"Yes": 1})
ADHD["Attention Deficit Hyperactivity Disorder"] = ADHD["Attention Deficit Hyperactivity Disorder.1"] + ADHD["Attention Deficit Hyperactivity Disorder.2"]

# differences add new column - ADHD

Personality = result[["Personality Disorder (Borderline, Antisocial, Paranoid, etc).1", "Personality Disorder (Borderline, Antisocial, Paranoid, etc).2"]]
Personality["Personality Disorder (Borderline, Antisocial, Paranoid, etc).1"] = Personality["Personality Disorder (Borderline, Antisocial, Paranoid, etc).1"].replace({"No": 0,"Yes": 1})
Personality["Personality Disorder (Borderline, Antisocial, Paranoid, etc).2"] = Personality["Personality Disorder (Borderline, Antisocial, Paranoid, etc).2"].replace({"No": 0,"Yes": 1})
Personality["Personality Disorder (Borderline, Antisocial, Paranoid, etc)"] = Personality["Personality Disorder (Borderline, Antisocial, Paranoid, etc).1"] + Personality["Personality Disorder (Borderline, Antisocial, Paranoid, etc).2"]

# differences add new column - Personality

OCD = result[["Obsessive-Compulsive Disorder.1", "Obsessive-Compulsive Disorder.2"]]
OCD["Obsessive-Compulsive Disorder.1"] = OCD["Obsessive-Compulsive Disorder.1"].replace({"No": 0,"Yes": 1})
OCD["Obsessive-Compulsive Disorder.2"] = OCD["Obsessive-Compulsive Disorder.2"].replace({"No": 0,"Yes": 1})
OCD["Obsessive-Compulsive Disorder"] = OCD["Obsessive-Compulsive Disorder.1"] + OCD["Obsessive-Compulsive Disorder.2"]

# differences add new column - OCD

PTSD = result[["Post-traumatic Stress Disorder", "Post-traumatic Stress Disorder.1"]]
PTSD["Post-traumatic Stress Disorder"] = PTSD["Post-traumatic Stress Disorder"].replace({"No": 0,"Yes": 1})
PTSD["Post-traumatic Stress Disorder.1"] = PTSD["Post-traumatic Stress Disorder.1"].replace({"No": 0,"Yes": 1})
PTSD["Post traumatic Stress Disorder"] = PTSD["Post-traumatic Stress Disorder"] + PTSD["Post-traumatic Stress Disorder.1"]

# differences add new column - PTSD

SRS = result[["Stress Response Syndromes.1", "Stress Response Syndromes.2"]]
SRS["Stress Response Syndromes.1"] = SRS["Stress Response Syndromes.1"].replace({"No": 0,"Yes": 1})
SRS["Stress Response Syndromes.2"] = SRS["Stress Response Syndromes.2"].replace({"No": 0,"Yes": 1})
SRS["Stress Response Syndromes"] = SRS["Stress Response Syndromes.1"] + SRS["Stress Response Syndromes.2"]

# differences add new column - SRS

DD = result[["Dissociative Disorder.1", "Dissociative Disorder.2"]]
DD["Dissociative Disorder.1"] = DD["Dissociative Disorder.1"].replace({"No": 0,"Yes": 1})
DD["Dissociative Disorder.2"] = DD["Dissociative Disorder.2"].replace({"No": 0,"Yes": 1})
DD["Dissociative Disorder"] = DD["Dissociative Disorder.1"] + DD["Dissociative Disorder.2"]

# differences add new column - DD

SUD = result[["Substance Use Disorder.1", "Substance Use Disorder.2"]]
SUD["Substance Use Disorder.1"] = SUD["Substance Use Disorder.1"].replace({"No": 0,"Yes": 1})
SUD["Substance Use Disorder.2"] = SUD["Substance Use Disorder.2"].replace({"No": 0,"Yes": 1})
SUD["Substance Use Disorder"] = SUD["Substance Use Disorder.1"] + SUD["Substance Use Disorder.2"]

# differences add new column - SUD

AD = result[["Addictive Disorder.1", "Addictive Disorder.2"]]
AD["Addictive Disorder.1"] = AD["Addictive Disorder.1"].replace({"No": 0,"Yes": 1})
AD["Addictive Disorder.2"] = AD["Addictive Disorder.2"].replace({"No": 0,"Yes": 1})
AD["Addictive Disorder"] = AD["Addictive Disorder.1"] + AD["Addictive Disorder.2"]

# differences add new column - AD

oth = result[["Other.1", "Other.2"]]
oth["Other.1"] = oth["Other.1"].replace({"N/A": 0,"Other": 1})
oth["Other.2"] = oth["Other.2"].replace({"N/A": 0,"Other": 1})
oth["Other"] = oth["Other.1"] + oth["Other.2"]

# differences add new column - Oth

# %%
reorganizedresult = result[['Number of employees', 'Is your employer a tech company?',
       'Does your medical coverage include treatment of mental health?',
       'Do you currently have a mental health disorder?',
       'Do you know the options for mental health care available under your employer-provided health coverage?',
       'Have you ever been diagnosed with a mental health disorder?',
       'Have you had a mental health disorder in the past?',
       'Do you have a family history of mental illness?', 'What is your age?',
       'What is your gender?', 'What country do you work in?',
       'What is your race?',
       'Is your primary role within your company related to tech/IT?',
       'Do you believe your productivity is ever affected by a mental health issue?',
       'How well do you think the tech industry supports employees with mental health issues?']]

reorganizedresult["Anxiety Disorder (Generalized, Social, Phobia, etc)"] = anxiety["Anxiety Disorder (Generalized, Social, Phobia, etc)"]
reorganizedresult["Mood Disorder (Depression, Bipolar Disorder, etc)"] = mood["Mood Disorder (Depression, Bipolar Disorder, etc)"]
reorganizedresult["Psychotic Disorder (Schizophrenia, Schizoaffective, etc)"] = Psychotic["Psychotic Disorder (Schizophrenia, Schizoaffective, etc)"]
reorganizedresult["Eating Disorder (Anorexia, Bulimia, etc)"] = Eating["Eating Disorder (Anorexia, Bulimia, etc)"]
reorganizedresult["Attention Deficit Hyperactivity Disorder"] = ADHD["Attention Deficit Hyperactivity Disorder"]
reorganizedresult["Personality Disorder (Borderline, Antisocial, Paranoid, etc)"] = Personality["Personality Disorder (Borderline, Antisocial, Paranoid, etc)"]
reorganizedresult["Obsessive-Compulsive Disorder"] = OCD["Obsessive-Compulsive Disorder"]
reorganizedresult["Post traumatic Stress Disorder"] = PTSD["Post traumatic Stress Disorder"]
reorganizedresult["Stress Response Syndromes"] = SRS["Stress Response Syndromes"]
reorganizedresult["Dissociative Disorder"] = DD["Dissociative Disorder"]
reorganizedresult["Substance Use Disorder"] = SUD["Substance Use Disorder"]
reorganizedresult["Addictive Disorder"] = AD["Addictive Disorder"]
reorganizedresult["Other"] = oth["Other"]

reorganizedresult["Anxiety Disorder (Generalized, Social, Phobia, etc)"] = reorganizedresult["Anxiety Disorder (Generalized, Social, Phobia, etc)"].replace({2: "Yes", 0: "No"})
reorganizedresult["Mood Disorder (Depression, Bipolar Disorder, etc)"] = reorganizedresult["Mood Disorder (Depression, Bipolar Disorder, etc)"].replace({1: "Yes", 0: "No"})
reorganizedresult["Psychotic Disorder (Schizophrenia, Schizoaffective, etc)"] = reorganizedresult["Psychotic Disorder (Schizophrenia, Schizoaffective, etc)"].replace({1: "Yes", 0: "No"})
reorganizedresult["Eating Disorder (Anorexia, Bulimia, etc)"] = reorganizedresult["Eating Disorder (Anorexia, Bulimia, etc)"].replace({1: "Yes", 0: "No"})
reorganizedresult["Attention Deficit Hyperactivity Disorder"] = reorganizedresult["Attention Deficit Hyperactivity Disorder"].replace({1: "Yes", 0: "No"})
reorganizedresult["Personality Disorder (Borderline, Antisocial, Paranoid, etc)"] = reorganizedresult["Personality Disorder (Borderline, Antisocial, Paranoid, etc)"].replace({1: "Yes", 0: "No"})
reorganizedresult["Obsessive-Compulsive Disorder"] = reorganizedresult["Obsessive-Compulsive Disorder"].replace({1: "Yes", 0: "No"})
reorganizedresult["Post traumatic Stress Disorder"] = reorganizedresult["Post traumatic Stress Disorder"].replace({1: "Yes", 0: "No"})
reorganizedresult["Stress Response Syndromes"] = reorganizedresult["Stress Response Syndromes"].replace({1: "Yes", 0: "No"})
reorganizedresult["Dissociative Disorder"] = reorganizedresult["Dissociative Disorder"].replace({1: "Yes", 0: "No"})
reorganizedresult["Substance Use Disorder"] = reorganizedresult["Substance Use Disorder"].replace({1: "Yes", 0: "No"})
reorganizedresult["Addictive Disorder"] = reorganizedresult["Addictive Disorder"].replace({1: "Yes", 0: "No"})
reorganizedresult["Other"] = reorganizedresult["Other"].replace({1: "Yes", 0: "No"})

# %%
reorganizedresult.to_csv("data_data.csv", index=False, header=True)
